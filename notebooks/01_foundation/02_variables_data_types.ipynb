# %% [markdown]
# # Variables & Data Types 📊
#
# ## Learning Objectives
# - Create and use variables
# - Understand data types: text, numbers, boolean
# - Convert between data types
# - Follow naming conventions
# - Apply variables in real scenarios
#
# ## Core Concepts
#
# **Variable:** Named container for data
# **Data Type:** Kind of data (text, number, true/false)
# **Assignment:** Storing data in variables
# **Conversion:** Changing data from one type to another

# %% [markdown]
# ## 1. Creating Variables

# %%
# Create variables: variable_name = value
name = "Alice"
age = 25
height = 5.6
is_student = True

# Use variables
print(name)
print(f"{name} is {age} years old")

# Variables can change
age = 26
print(f"Next year: {age}")

# %% [markdown]
# ## 2. Data Types

# %%
# String (text) - use quotes
name = "Bob"
message = "Hello World"
color = 'blue'

print("Text examples:")
print(f"Name: {name}")
print(f"Message: {message}")
print(f"Color: {color}")

# Integer (whole numbers)
age = 30
score = 100
temperature = -5

print("\nWhole numbers:")
print(f"Age: {age}")
print(f"Score: {score}")
print(f"Temperature: {temperature}")

# Float (decimal numbers)
height = 5.8
price = 19.99
pi = 3.14

print("\nDecimal numbers:")
print(f"Height: {height}")
print(f"Price: ${price}")
print(f"Pi: {pi}")

# Boolean (True/False)
is_sunny = True
is_raining = False
has_license = True

print(f"\nTrue/False values:")
print(f"Sunny today: {is_sunny}")
print(f"Raining: {is_raining}")
print(f"Has license: {has_license}")

# Check data types
print(f"\nData type examples:")
print(f"type(name): {type(name)}")
print(f"type(age): {type(age)}")
print(f"type(height): {type(height)}")
print(f"type(is_sunny): {type(is_sunny)}")

# %% [markdown]
# ## 3. Type Conversion & Operations

# %%
# Converting between types
age_text = "25"
age_number = int(age_text)
print(f"Text '{age_text}' → Number {age_number}")

price_text = "19.99" 
price_number = float(price_text)
print(f"Text '{price_text}' → Number {price_number}")

score = 85
score_text = str(score)
print(f"Number {score} → Text '{score_text}'")

# Math with variables
a, b = 10, 3
print(f"\nMath: a={a}, b={b}")
print(f"a + b = {a + b}")
print(f"a * b = {a * b}")
print(f"a / b = {a / b:.2f}")

# Text operations
first = "John"
last = "Smith"
full_name = first + " " + last
print(f"\nText: '{first}' + ' ' + '{last}' = '{full_name}'")
print(f"Length: {len(full_name)} characters")

# %% [markdown]
# ## Practice Exercises

# %%
# Exercise 1: Personal info
my_name = "Put your name here"
my_age = 25
my_city = "Your city"
likes_coding = True

print("📝 Personal Profile:")
print(f"Name: {my_name}")
print(f"Age: {my_age}")
print(f"City: {my_city}")
print(f"Likes coding: {likes_coding}")

# Exercise 2: Calculator
num1, num2 = 15, 7
print(f"\n📝 Calculator:")
print(f"{num1} + {num2} = {num1 + num2}")
print(f"{num1} - {num2} = {num1 - num2}")
print(f"{num1} * {num2} = {num1 * num2}")

# Exercise 3: Shopping
item_name = "Laptop"
item_price = 999.99
quantity = 2
total = item_price * quantity

print(f"\n📝 Shopping:")
print(f"Item: {item_name}")
print(f"Price: ${item_price}")
print(f"Quantity: {quantity}")
print(f"Total: ${total}")

# Exercise 4: Type conversion
birth_year = "1995"
current_year = 2024
age = current_year - int(birth_year)

print(f"\n📝 Age from birth year:")
print(f"Born: {birth_year}")
print(f"Current year: {current_year}")
print(f"Age: {age}")

print("\n" + "="*40)
print("✅ Variables & Data Types Complete!")
print("Key Skills:")
print("• Variables store data")
print("• str (text), int (whole #), float (decimal), bool (T/F)")
print("• int(), float(), str() convert types")
print("• Use descriptive variable names")
print("\n➡️  Next: Basic Operations (math & comparisons)")

# %% [markdown]
# # User Input & Output 📝
#
# ## Learning Objectives
# - Get user input with `input()`
# - Display output with `print()`
# - Convert text input to numbers
# - Format output professionally
# - Build interactive programs
#
# ## Core Concepts
#
# **Input:** Getting data from users
# **Output:** Showing results to users
# **Conversion:** Changing text to numbers for math
#
# *Example: Ask user's age → Calculate birth year → Display result*

# %%
# Basic output with print()
print("Hello, World!")
print("Python is awesome!")

# Multiple items and separators
print("Name:", "Alice", "Age:", 25)
print("apple", "banana", "orange", sep=", ")
print("2024", "08", "27", sep="-")

# Formatted output with f-strings
name = "Bob"
age = 30
score = 85.7

print(f"Hello, {name}!")
print(f"You are {age} years old")
print(f"Your score is {score}")

# Number formatting
price = 19.99
print(f"Price: ${price:.2f}")

percentage = 0.75
print(f"Success rate: {percentage:.1%}")

# %%
# =============================================================================
# PRACTICE EXERCISES
# =============================================================================

print("PRACTICE EXERCISES")
print("=" * 30)

# Exercise 1: Basic greeting
print("\n📝 Exercise 1: Greeting Program")
name = "Sarah"  # Simulate input
print(f"Hello, {name}! Welcome to Python!")

# Exercise 2: Age calculator  
print("\n📝 Exercise 2: Age Calculator")
birth_year = "1998"
current_year = 2024
age = current_year - int(birth_year)
print(f"Born in {birth_year}, you are {age} years old")

# Exercise 3: Simple calculator
print("\n📝 Exercise 3: Calculator")
num1, num2 = "12", "8"
a, b = int(num1), int(num2)
print(f"{a} + {b} = {a + b}")
print(f"{a} * {b} = {a * b}")

# Exercise 4: Personal profile
print("\n📝 Exercise 4: Profile Card")
first = "Alex"
last = "Johnson" 
age = "22"
city = "Seattle"

print(f"--- PROFILE ---")
print(f"Name: {first} {last}")
print(f"Age: {age}")
print(f"City: {city}")

# Exercise 5: Shopping calculator
print("\n📝 Exercise 5: Shopping Total")
item = "Book"
price = "29.99"
quantity = "3"

total = float(price) * int(quantity)
print(f"Item: {item}")
print(f"Price: ${price} x {quantity}")
print(f"Total: ${total:.2f}")

print("\n" + "="*40)
print("✅ Input/Output Complete!")
print("Key Skills:")
print("• input() - Get user data")
print("• print() - Show output") 
print("• int()/float() - Convert types")
print("• f-strings - Format text")
print("\n➡️  Next: Conditionals (if/else statements)")
